# %%
import time

# Start Tick
start = time.time()

# Example Algorithm (Loop)
for i in range(1000000):
    pass   # yahan algorithm chalega

# End Tick
end = time.time()

# Difference
execution_time = end - start

print("Execution Time:", execution_time, "seconds")
# Out:
# Execution Time: 0.08845996856689453 seconds
