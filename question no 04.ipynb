# %% [markdown]
# Question 4: [Marks 5]
# Define a function process_numbers(nums) that:
# • Take a list of 15 integer elements from user, list have duplicate values.
# • Removes duplicates, sorts the list, and returns a tuple of (max, min, sum, average) using built-in
# functions.
# • Call this function in the main program and print results.

# %%
def process_numbers(nums):
    nums = list(set(nums))

    nums.sort()

    maximum = max(nums)
    minimum = min(nums)
    total = sum(nums)
    average = total / len(nums)

    return (maximum, minimum, total, average)

numbers = []

print("Enter 15 integer numbers (duplicates allowed):")
for i in range(15):
    n = int(input(f"Enter number {i+1}: "))
    numbers.append(n)

result = process_numbers(numbers)

print("\nAfter removing duplicates and sorting:")
print("Numbers:", sorted(list(set(numbers))))
print("\nResults (Max, Min, Sum, Average):")
print(result)
# Out:
# Enter 15 integer numbers (duplicates allowed):
# Enter number 1: 23
# Enter number 2: 23
# Enter number 3: 43
# Enter number 4: 12
# Enter number 5: 33
# Enter number 6: 54
# Enter number 7: 65
# Enter number 8: 46
# Enter number 9: 355
# Enter number 10: 3333
# Enter number 11: 6554
# Enter number 12: 6444
# Enter number 13: 23
# Enter number 14: 43
# Enter number 15: 64
#
# After removing duplicates and sorting:
# Numbers: [12, 23, 33, 43, 46, 54, 64, 65, 355, 3333, 6444, 6554]
#
# Results (Max, Min, Sum, Average):
# (6554, 12, 17026, 1418.8333333333333)
