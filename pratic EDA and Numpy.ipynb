# %% [markdown]
# M.Talha Ramzan
# ---
# 2330-0141
# ---
# BS AI
# ---
# lab 02

# %%
import pandas as pd

# Read the Excel sheet
df = pd.read_excel("/content/churn.xlsx")

# %%
# Question 1: Head in transpose mode
df.head().T
# Out:
#                                  0             1               2  \
# customerID              7590-VHVEG    5575-GNVDE      3668-QPYBK
# gender                      Female          Male            Male
# SeniorCitizen                    0             0               0
# Partner                        Yes            No              No
# Dependents                      No            No              No
# tenure                           1            34               2
# PhoneService                    No           Yes             Yes
# MultipleLines     No phone service            No              No
# InternetService                DSL           DSL             DSL
# OnlineSecurity                  No           Yes             Yes
# OnlineBackup                   Yes            No             Yes
# DeviceProtection                No           Yes              No
# TechSupport                     No            No              No
# ...

# %%
# Question 2: Tail in transpose mode
df.tail().T
# Out:
#                           7038                     7039              7040  \
# customerID          6840-RESVB               2234-XADUH        4801-JZAZL
# gender                    Male                   Female            Female
# SeniorCitizen                0                        0                 0
# Partner                    Yes                      Yes               Yes
# Dependents                 Yes                      Yes               Yes
# tenure                      24                       72                11
# PhoneService               Yes                      Yes                No
# MultipleLines              Yes                      Yes  No phone service
# InternetService            DSL              Fiber optic               DSL
# OnlineSecurity             Yes                       No               Yes
# OnlineBackup                No                      Yes                No
# DeviceProtection           Yes                      Yes                No
# ...

# %%
# Question 3: 10 random entries
df.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5719  1089-XZWHH  Female              0     Yes        Yes      24
# 2956  5649-RXQTV    Male              0      No         No      51
# 296   6556-DBKZF  Female              0     Yes        Yes      71
# 575   9548-LIGTA    Male              0     Yes         No      61
# 315   5027-YOCXN    Male              0     Yes        Yes      51
# 6113  1228-ZLNBX    Male              0      No         No      21
# 1415  5223-UZAVK    Male              0      No         No      64
# 6057  4003-FUSHP    Male              0      No         No      19
# 3927  4390-KYULV    Male              0     Yes         No       3
# 1863  9575-IWCAZ    Male              0     Yes         No       6
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 5719          Yes            No              No  No internet service  ...
# 2956          Yes            No     Fiber optic                   No  ...
# ...

# %%
# Question 4: Shape and columns
df.shape, df.columns.tolist()
# Out:
# ((7043, 21),
#  ['customerID',
#   'gender',
#   'SeniorCitizen',
#   'Partner',
#   'Dependents',
#   'tenure',
#   'PhoneService',
#   'MultipleLines',
#   'InternetService',
#   'OnlineSecurity',
#   'OnlineBackup',
#   'DeviceProtection',
#   'TechSupport',
#   'StreamingTV',
#   'StreamingMovies',
#   'Contract',
#   'PaperlessBilling',
#   'PaymentMethod',
#   'MonthlyCharges',
#   'TotalCharges',
#   'Churn'])

# %%
# Question 5: Sum of TotalCharges
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df['TotalCharges'].sum()
# Out:
# np.float64(16056168.7)

# %%
# Question 6: Tenure as array
tenure_array = df['tenure'].values
tenure_array
# Out:
# array([ 1, 34,  2, ..., 11,  4, 66])

# %%
# Question 7: Max, Min, Mean
tenure_array.max(), tenure_array.min(), tenure_array.mean()
# Out:
# (np.int64(72), np.int64(0), np.float64(32.37114865824223))

# %%
# Question 8: Average MonthlyCharges
df['MonthlyCharges'].mean()
# Out:
# np.float64(64.76169246059918)

# %%
# Question 9: Sum MonthlyCharges
df['MonthlyCharges'].sum()
# Out:
# np.float64(456116.6)

# %%
# Question 10: Drop customerID
df = df.drop(columns=['customerID'])
df.columns.tolist()
# Out:
# ['gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %%
# Question 11: Null values in each column
df.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# Question 12: Mean of Tenure
df['tenure'].mean()
# Out:
# np.float64(32.37114865824223)

# %%
# Question 13: Count items in InternetService
df['InternetService'].value_counts()
# Out:
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
#question no 14
area_col = [c for c in df.columns if 'area' in c.lower() and 'code' in c.lower()]

if area_col:
    print("Number of unique values in area code:", df[area_col[0]].nunique())
else:
    print("Area code column not found")
# Out:
# Area code column not found

# %%
# Question 15: Rows 0-10 of 'total day charge'
df.loc[0:10, 'total day charge'] if 'total day charge' in df.columns else "Column not found"
# Out:
# 'Column not found'

# %% [markdown]
# Part 2: NumPy Exercises

# %%
import numpy as np

# Random arrays
array1 = np.random.randint(50, 100, size=10)
array2 = np.random.randint(50, 100, size=10)
array1, array2
# Out:
# (array([81, 97, 95, 63, 66, 77, 67, 93, 58, 53]),
#  array([56, 78, 79, 84, 84, 67, 83, 90, 93, 73]))

# %%
# Question 1: Sum of array1 and array2
array1 + array2
# Out:
# array([137, 175, 174, 147, 150, 144, 150, 183, 151, 126])

# %%
# Question 2: Dot product
np.dot(array1, array2)
# Out:
# np.int64(58796)

# %%
# Question 3: Cross product
np.cross(array1[:3], array2[:3])
# Out:
# array([  253, -1079,   886])

# %%
# Question 4: Element-wise product
array1 * array2
# Out:
# array([4536, 7566, 7505, 5292, 5544, 5159, 5561, 8370, 5394, 3869])

# %%
# Question 5: Transpose of array1
array1.T
# Out:
# array([81, 97, 95, 63, 66, 77, 67, 93, 58, 53])

# %%
# Question 6: Element-wise addition
array1 + array2
# Out:
# array([137, 175, 174, 147, 150, 144, 150, 183, 151, 126])

# %%
# Question 7: Element-wise subtraction
array1 - array2
# Out:
# array([ 25,  19,  16, -21, -18,  10, -16,   3, -35, -20])

# %%
# Question 8: Element-wise multiplication
array1 * array2
# Out:
# array([4536, 7566, 7505, 5292, 5544, 5159, 5561, 8370, 5394, 3869])

# %%
# Question 9: Element-wise division
array1 / array2
# Out:
# array([1.44642857, 1.24358974, 1.20253165, 0.75      , 0.78571429,
#        1.14925373, 0.80722892, 1.03333333, 0.62365591, 0.7260274 ])

# %%
# Question 10: Array1 squared
array1 ** 2
# Out:
# array([6561, 9409, 9025, 3969, 4356, 5929, 4489, 8649, 3364, 2809])

# %%
# Question 11: Square root of array2
np.sqrt(array2)
# Out:
# array([7.48331477, 8.83176087, 8.88819442, 9.16515139, 9.16515139,
#        8.18535277, 9.11043358, 9.48683298, 9.64365076, 8.54400375])

# %%
# Question 12: Exponential of array1
np.exp(array1.astype(float))
# Out:
# array([1.50609731e+35, 1.33833472e+42, 1.81123908e+41, 2.29378316e+27,
#        4.60718663e+28, 2.75851345e+33, 1.25236317e+29, 2.45124554e+40,
#        1.54553894e+25, 1.04137594e+23])

# %%
# Question 13: Natural log of array2
np.log(array2)
# Out:
# array([4.02535169, 4.35670883, 4.36944785, 4.4308168 , 4.4308168 ,
#        4.20469262, 4.41884061, 4.49980967, 4.53259949, 4.29045944])

# %%
# Question 14: Absolute value of array1
np.abs(array1)
# Out:
# array([81, 97, 95, 63, 66, 77, 67, 93, 58, 53])

# %%
# Question 15: Minimum value in array2
np.min(array2)
# Out:
# np.int64(56)
