# %%
from sklearn.preprocessing import MinMaxScaler

data = [[10], [20], [30], [40]]

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

print(scaled_data)
# Out:
# [[0.        ]
#  [0.33333333]
#  [0.66666667]
#  [1.        ]]
