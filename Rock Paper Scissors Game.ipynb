# %%
import random

print("🎮 Welcome Haji Talha!")
print("Rock 🪨  Paper 📄  Scissors ✂")
print("Type: rock, paper, scissors")
print("Type 'exit' to quit\n")

choices = ["rock", "paper", "scissors"]

while True:
    user = input("Your choice: ").lower()

    if user == "exit":
        print("Game Ended. Thanks for playing Haji Talha!")
        break

    if user not in choices:
        print("Invalid choice! Try again.\n")
        continue

    computer = random.choice(choices)
    print("Computer chose:", computer)

    if user == computer:
        print("🤝 It's a Draw!")
    elif (user == "rock" and computer == "scissors") or \
         (user == "paper" and computer == "rock") or \
         (user == "scissors" and computer == "paper"):
        print("🎉 You Win Haji Talha!")
    else:
        print("😢 Computer Wins!")

    print("----------------------\n")
# Out:
# 🎮 Welcome Haji Talha!
# Rock 🪨  Paper 📄  Scissors ✂
# Type: rock, paper, scissors
# Type 'exit' to quit
#
# Your choice: rock
# Computer chose: scissors
# 🎉 You Win Haji Talha!
# ----------------------
#
# Your choice: paper
# Computer chose: rock
# 🎉 You Win Haji Talha!
# ----------------------
#
# Your choice: rock
# Computer chose: paper
# 😢 Computer Wins!
# ----------------------
#
# Your choice: exit
# Game Ended. Thanks for playing Haji Talha!
